# %% [markdown]
# # Variable smoke tests

# %%
import numpy as np\nimport xarray as xr\nfrom ocean_viz.derived import current_speed, thermal_habitat_mask\nu = xr.DataArray(np.array([[0.2, 0.4]]), dims=['lat','lon'])\nv = xr.DataArray(np.array([[0.3, 0.1]]), dims=['lat','lon'])\ncurrent_speed(u, v)
